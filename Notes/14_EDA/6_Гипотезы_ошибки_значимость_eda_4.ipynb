# %% [markdown]
# # <center> Статистические тесты

# %% [markdown]
# >**Генеральной совокупностью** называется всё множество интересующих нас объектов, а **выборкой** — случайное подмножество этого множества.

# %% [markdown]
# Мы уже знаем, что на основе выборки (части наблюдений) можно измерить следующие показатели:
# * выборочное среднее (центральная мера распределения);
# * выборочное стандартное отклонение (мера разброса);
# * выборочная пропорция.
#
# Однако на самом деле нас всегда интересуют параметры генеральной совокупности:
# * истинное среднее — **математическое ожидание** ($\mu$, «мю»);
# * истинное стандартное отклонение ($\sigma$, «сигма»);
# * истинная пропорция ($p$).

# %% [markdown]
# * Статистические тесты позволяют сделать выводы о всей генеральной совокупности по выборке.
# * Статистические тесты нужны в случаях, когда мы не можем измерить все объекты в генеральной совокупности.
# * Без статистических тестов выводы, полученные на выборке, нельзя распространить на всю генеральную совокупность.

# %% [markdown]
# ---

# %% [markdown]
# >**Статистическая гипотеза** — это некоторое утверждение о параметрах генеральной совокупности, которое мы будем проверять на основе данных выборки. Например, утверждение «рекомендательная система влияет на средний чек покупки» — это статистическая гипотеза.

# %% [markdown]
# Примечание. Здесь и далее под «средним чеком покупки» мы будем иметь в виду средний чек на всей генеральной совокупности, то есть математическое ожидание среднего чека.

# %% [markdown]
# ### <center> АЛГОРИТМ ПРОВЕРКИ СТАТИСТИЧЕСКИХ ГИПОТЕЗ

# %% [markdown]
# Общий алгоритм проверки гипотезы состоит из шести этапов:
# 1. Построение нулевой и альтернативной гипотез.
# 2. Выбор уровня значимости $\alpha$.
# 3. Сбор данных для проверки гипотезы.
# 4. Выбор статистического теста.
# 5. Проведение статистического теста, вычисление **p-value**.
# 6. Сравнение **p-value** c уровнем значимости  и вывод, отклонить или не отклонить нулевую гипотезу.

# %% [markdown]
# ### <center> НУЛЕВАЯ И АЛЬТЕРНАТИВНАЯ ГИПОТЕЗЫ

# %% [markdown]
# Проведение статистических тестов начинается с формулирования двух конкурирующих между собой статистических гипотез — **нулевой** и **альтернативной**.

# %% [markdown]
# В качестве **нулевой** гипотезы ($H_0$) обычно берётся утверждение об **отсутствии эффекта**, т. е. тех изменений, которых мы ожидали, нет.
#
# В качестве **альтернативной** гипотезы ($H_1$) берётся утверждение о **наличии эффекта** (обратное нулевой гипотезе), т. е. те изменения, которых мы ожидали, есть.

# %% [markdown]
# В ходе статистических тестов мы будем проверять нулевую гипотезу. Возможен один из двух результатов:
# * **отклоняем нулевую гипотезу** в пользу альтернативной (делаем вывод, что эффект есть);
# * **не отклоняем нулевую гипотезу**, так как для этого недостаточно оснований (нельзя сделать вывод о наличии эффекта).

# %% [markdown]
# Существует три варианта формулировки нулевой и альтернативной гипотез. Давайте рассмотрим формулировки вместе с их математической интерпретацией. Пусть $\mu_1$ — средний чек покупки без просмотра рекомендаций, $\mu_2$ — средний чек покупки после просмотра рекомендаций.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Альтернативная гипотеза вида $H_1 : \mu_1 \neq \mu_2$ называется **двусторонней**, альтернативные гипотезы $H_1: \mu_1 < \mu_2$ и $H_1: \mu_1 >\mu_2$ — **односторонними**. При этом гипотеза $H_1: \mu_1 < \mu_2$ называется **левосторонней**, а гипотеза $H_1: \mu_1 >\mu_2$ — **правосторонней**.

# %% [markdown]
# ## <center> Статистическая значимость

# %% [markdown]
# Наша задача как профессионалов в анализе данных — уметь корректно формулировать гипотезы, проверять их на имеющихся данных и объяснять результаты команде. Однако от нас требуется не только определить, подтверждают ли гипотезу имеющиеся данные, но и ответить на вопрос, насколько мы уверены в своём заключении, иными словами — насколько **статистически значимы** полученные нами результаты.
#
# Чтобы ответить на этот вопрос, нужно понять, какие ошибки мы можем допустить при проверке гипотез, а также познакомиться с понятием статистической значимости (*p-value*).

# %% [markdown]
# ### <center> ОШИБКИ I И II РОДА

# %% [markdown]
# При проверке гипотезы возможно допустить ошибку одного из двух видов:
# * **Ошибка I (первого) рода**: отклонение нулевой гипотезы, когда она на самом деле верна. Эта ошибка также называется **$\alpha$-ошибкой, или ложноположительным результатом**.
# * **Ошибка II (второго) рода**: неотклонение нулевой гипотезы, когда она на самом деле ложна. Эта ошибка также называется **$\beta$-ошибкой, или ложноотрицательным результатом.**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# >**Примечание**. Вероятность не допустить ошибку II рода (1 - $\beta$) ещё называют **мощностью теста**. Например, если мощность теста составила 0.93, это значит, что вероятность того, что была допущена ошибка II рода, составляет 0.07 (7 %).

# %% [markdown]
# >Задание 4.2 (на самопроверку)
#
# Для приведённых ниже бизнес-вопросов самостоятельно сформулируйте нулевую и альтернативную гипотезы, а также смысл ошибок первого и второго рода:
# * Уменьшается ли время ответа техподдержки благодаря использованию нового классификатора запросов?
# * Увеличивается ли время работы изделий при использовании материалов от нового поставщика?

# %% [markdown]
# 1. 1. $\mu_1$ - мат. ожидание времени ответа тех.поддержки до использования нового классикикатора
#    2. $\mu_2$ - мат. ожидание времени ответа тех.поддержки после использования нового классикикатора
#    3. $H_0$ - нулевая гипотеза - $\mu_2 \geq \mu_1$ - время ожидания после введения осталось таким же или стало больше
#    4. $H_1$ - альтернативная гипотеза - $\mu_2 < \mu_1$ - время ожидания после введения уменьшилось
#    5. Ошибка 1 рода - отклонение $H_0$, хотя она верна. Сделан вывод, что время время ответа уменьшилось, хотя это было не так.
#    6. Ошибка 2 рода - принятие $H_0$, хотя она ошибочна. Сделан вывод, что время ответа увеличится или останется таким же. Новый классификатор не ввели
# 2. 1. $\mu_1$ - мат. ожидание времени работы изделия от старого поставщика
#    2. $\mu_2$ - мат. ожидание времени работы изделия от нового поставщика
#    3. $H_0$ - нулевая гипотеза - $\mu_2 <= \mu_1$ - время работы изделий с материалами от нового поставщика не увеличивается
#    4. $H_1$ - альтернативная гипотеза - $\mu_2 > \mu_1$ - время работы изделий с материалами от нового поставщика  увеличивается
#    5. Ошибка 1 рода - отклонение $H_0$ при ее верности. Сделан вывод, что время работы изделий с материалами от нового поставщика  увеличивается
#    6. Ошибка 2 рода - принятие $H_0$ при ее ошибочности. Сделан вывод, что смена поставщика неактуальна и время работы изделий с материалами от нового поставщика не увеличивается

# %% [markdown]
# ## <center> СТАТИСТИЧЕСКАЯ ЗНАЧИМОСТЬ (P-VALUE)

# %% [markdown]
# Для визуализации идеи статистической значимости мы будем использовать график плотности распределения вероятности, а именно **график оценки плотности ядра (Kernel Density Estimation, KDE)**. Он представляет собой непрерывную кривую, которая показывает распределение значений, и выглядит как сглаженная гистограмма. По такому графику проще понять форму распределения (пики, симметричность), чем по гистограмме.

# %% [markdown]
# По оси $x$ отложено значение случайной величины (например, размера чека), а по оси $y$ — плотность вероятности (чем больше y, тем больше вероятность наблюдать значение по оси $x$)
# [Детали построения графиков плотности вероятностей](https://www.geeksforgeeks.org/maths/probability-density-function-meaning-formula-and-graph/)

# %% [markdown]
# Примеры графиков плотности распределения вероятности (оранжевые) с соответствующими гистограммами:
# ![image.png](attachment:image.png)

# %% [markdown]
# График плотности вероятности построен так, что вся площадь под кривой равна 1 — это вероятность всех возможных значений размера чека. Это следует из основного правила теории вероятностей: сумма вероятностей всех исходов (всех возможных значений чека) всегда равна 1.

# %% [markdown]
# Площадь под кривой на интервале от $a$ до $b$ (голубая область) соответствует вероятности получить среднее значение от $a$ до $b$ (на графике ниже такая вероятность ~0.3):

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Например, если $a = 350$, а $b=500$, это значит, что вероятность того, что средний чек покупки в онлайн-магазине находится в диапазоне от 350 до 500 рублей составляет 0.3.

# %% [markdown]
# >Уровнем **статистической значимости** (p-value, p-значением) называется вероятность получить наблюдаемые или более экстремальные значения при условии, что нулевая гипотеза верна.

# %% [markdown]
# Рассмотрим это определение на примере ответа на вопрос «Средний чек покупки в онлайн-магазине больше 500 рублей?». Гипотезы будут следующими:

# %% [markdown]
# **Нулевая гипотеза** - $H_0: \mu <= 500$ Средний чек покупки меньше или равен 500 рублей.
#
# **Альтернативная гипотеза** - $H_1: \mu >500$ Средний чек покупки больше 500 рублей.

# %% [markdown]
# Сначала допустим, что верна нулевая гипотеза: средний чек покупки (на генеральной совокупности) меньше или равен 500 рублей.
#
# Нам неизвестно, какой будет истинная форма плотности вероятности чека, которая получается на основе генеральной совокупности. Обычно предполагают какую-то форму из стандартных законов распределений, например, из нормального закона распределения, как на графике ниже (о нормальном распределении и его свойствах мы поговорим далее). Синяя пунктирная линия соответствует среднему чеку в 500 рублей, вокруг которого мы строим нулевую гипотезу:
# ![image.png](attachment:image.png)

# %% [markdown]
# Пусть на выборке мы получили средний размер чека 700 рублей. Отметим это значение на графике:
# ![image.png](attachment:image.png)

# %% [markdown]
# Какова вероятность получить такой же (700 рублей) или ещё больший средний чек при условии, что средний чек равен 500 рублям? Этой вероятностью будет площадь под кривой от 700 к большим значениям (p-value = p):
# ![image.png](attachment:image.png)

# %% [markdown]
# Чем больше было бы число, которое мы получили на выборке:
# * тем меньше была бы площадь под кривой, т. е. меньше полученное значение p-value;
# * тем меньше полученное наблюдение соответствовало бы нулевой гипотезе, согласно которой среднее значение чека — 500 рублей или меньше.

# %% [markdown]
# >Важно понимать, что p-value — это именно вероятность получить наблюдаемые или более экстремальные значения, если верна нулевая гипотеза, а не вероятность верности нулевой гипотезы.

# %% [markdown]
# Следующее необходимое нам понятие — уровень значимости.

# %% [markdown]
# >**Уровень значимости** — это пороговая вероятность допустить ошибку I рода (вероятность отклонить нулевую гипотезу, когда она верна). Обычно это число обозначается за $\alpha$.

# %% [markdown]
# Если полученное значение p-value меньше заранее заданного уровня значимости $\alpha$, мы отвергаем нулевую гипотезу. В таком случае принято говорить, что мы обнаружили статистически значимый эффект. Чаще всего в бизнесе берут $\alpha=0.05$. Это означает, что мы готовы к 5 % риску допустить ошибку I-ого рода (то есть сделать вывод, что эффект есть, хотя на самом деле его нет).

# %% [markdown]
# Итак:
# * Если полученное **p-value ниже уровня значимости** ($p<\alpha$), результаты статистически значимы и согласуются с альтернативной гипотезой.
# * Если полученное **p-value выше уровня значимости** ($p>\alpha$), результаты считаются статистически незначимыми, нельзя отвергнуть нулевую гипотезу.

# %% [markdown]
# >Примечание. Если p-value равно уровню значимости ($p=\alpha$), то возникает дилемма: принять нулевую гипотезу или отвергнуть её в зависимости от предварительных условий. На практике, если не оговорено других предварительных условий, в большинстве случаев нулевую гипотезу отвергают, если $p<= \alpha$.

# %% [markdown]
# Иллюстрация принятия решения для проверки гипотезы:
# ![image.png](attachment:image.png)

# %% [markdown]
# В нашем примере p-value = 0.03 (пока мы опустили детали вычисления). Это означает, что, если нулевая гипотеза верна, вероятность получить на выборке чек, который больше среднего чека на 200 и более рублей, составляет 0.03. Иллюстрация выглядит так:
# ![image.png](attachment:image.png)

# %% [markdown]
# Площадь жёлтой области равняется p-value (0.03), площадь красной области равняется $\alpha$ (0.05). P-value меньше $\alpha$ — значит, мы можем отвергнуть нулевую гипотезу в пользу альтернативной и сказать, что средний чек покупки больше 500 рублей.

# %% [markdown]
# ##  $\alpha$  ПРИ ОДНОСТОРОННИХ И ДВУСТОРОННИХ ГИПОТЕЗАХ

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Выше мы приводили иллюстрацию принятия решения для проверки односторонней (правосторонней) гипотезы:
# * одна область отклонения нулевой гипотезы (справа);
# * площадь области = $\alpha$.
#
# Аналогичная иллюстрация для левосторонней гипотезы:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Для двусторонней гипотезы иллюстрация будет следующей:
# * две области отклонения нулевой гипотезы (справа и слева);
# * площадь каждой области = $\frac{\alpha}{2}$.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# >Получается, что мы отвергаем двустороннюю гипотезу при более несовместимых с нулевой гипотезой данных, так как смотрим на различия в обе стороны — и в большую, и в меньшую. В каждой из сторон мы смотрим на более экстремальные значения, чем при односторонних гипотезах.

# %% [markdown]
# ## КАК ВЫБРАТЬ $\alpha$?

# %% [markdown]
# Уровень значимости $\alpha$ используют как порог для принятия решений, задающий приемлемый уровень ошибки I рода. Например, $\alpha$ = 0.05 означает, что мы готовы к риску в 5 % случаев сделать вывод о существовании искомого эффекта, когда в реальности его нет.
#
# Значение $\alpha$ необходимо выбрать до начала исследования совместно с бизнес-заказчиком. Единственно верного значения $\alpha$ не существует — оно зависит от бизнес-задачи. Обычно выбирают 0.01, 0.05 или 0.10.

# %% [markdown]
# >Примечание. При решении задач в этом модуле мы всегда будем использовать уровень значимости $\alpha$ = 0.05.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Чем более нежелательно допустить ошибку I рода, тем меньшее значение $\alpha$ стоит выбирать. Например, уровень значимости при испытаниях нового автомобильного оборудования будет ниже, чем уровень значимости при исследовании новой версии сайта.
#
# Возникает вполне логичный вопрос: почему бы не принять $\alpha$ = 0, тем самым исключив возможность ошибки?
#
# Увы, всё не так просто. Дело в том, что, помимо $\alpha$ , мы должны учитывать и $\beta$ — вероятность ошибки II рода (риск ложноотрицательного результата). Две этих величины противоречат друг другу. Предположим, вы хотите минимизировать ошибку первого рода. Тогда можно всегда принимать нулевую гипотезу $H_0$ вне зависимости от наблюдаемых данных — ошибки I рода не случится. Однако такое решение будет поднимать вероятность ошибки II рода (ошибки принятия нулевой гипотезы, когда она на самом деле ложна). Компромисс между этими параметрами показан ниже.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# На рисунке выше мы видим две кривые: синим показана вероятность получить наблюдаемые данные, если верна нулевая гипотеза; зелёным — вероятность получить их, если верна альтернативная гипотеза. Ошибки I и II рода возникают там, где эти два распределения перекрываются. Например, в точке пересечения зелёной и синей линий вероятности получить наблюдаемые данные равны — выбрать между гипотезами будет затруднительно.
#
# Область, заштрихованная синим цветом, представляет собой $\alpha$ — вероятность ошибки I рода, а область, заштрихованная зелёным цветом — $\beta$, вероятность ошибки II рода. Установив частоту ошибок I рода, вы также косвенно влияете на частоту ошибок II рода.
