# %%
#Пример операторов членства

print('me' in 'membership')
print('mes' not in 'membership')
# Out:
# True
# True

# %%
#Пример операторов тождественности
print(1 is '1')
print(2 is not '2')
# Out:
# False
# True
# <>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# C:\Users\1\AppData\Local\Temp\ipykernel_1484\994536082.py:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   print(1 is '1')
# C:\Users\1\AppData\Local\Temp\ipykernel_1484\994536082.py:3: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   print(2 is not '2')

# %%
#Пример функции Zip

print(list(zip([1,2,3], ['apple', 'grape', 'orange'], ['x', 2, True])))

for num, fruit, thing in zip([1,2,3], ['apple', 'grape', 'orange'], ['x', 2, True]):
    print(num)
    print(fruit)
    print(thing)
# Out:
# [(1, 'apple', 'x'), (2, 'grape', 2), (3, 'orange', True)]
# 1
# apple
# x
# 2
# grape
# 2
# 3
# orange
# True

# %% [markdown]
# -----

# %% [markdown]
# Что такое PYTHONPATH?
# PYTHONPATH — это переменная окружения, которая при импорте проверяется на наличие импортированных модулей в различных каталогах. Интерпретатор использует её, чтобы определить, какой модуль следует загрузить.

# %% [markdown]
# -----

# %% [markdown]
# Что такое pickling и unpickling?
# Модуль pickle принимает любой объект Python, преобразует его в строковое представление и сохраняет в файл с помощью функции dump, такой процесс называется pickling. Процесс извлечения исходных объектов Python из сохраненного строкового представления называется unpickling.

# %% [markdown]
# ```python
# import pickle
#
# a = 1
#
# #Процесс pickling
# pickle.dump(a, open('file.sav', 'wb'))
#
# #Процесс unpickling
# file = pickle.load(open('file.sav', 'rb'))
# ```

# %% [markdown]
# -------

# %% [markdown]
# Как вычислять процентили с помощью NumPy?
# Медиана — это 50 процентиль по определению. 25 процентиль указывает, что 25% наблюдаемых меньше числа в процентиле, то есть n процентов наблюдаемых значений меньше значения в процентиле n.
#
# Мы можем вычислить его с помощью NumPy, используя следующий код:
# ```python
# import numpy as np
#
# a = np.array([i for i in range(100)])
# p = np.percentile(a, 50) #Возвращает 50-ый перцентиль - медиану
#
# print(p)
# ```

# %% [markdown]
# ---

# %% [markdown]
# Как получить текущий рабочий каталог с помощью Python?
# Работая с Python, вам может понадобиться читать и записывать файлы из различных каталогов. Чтобы узнать, в каком вы сейчас работаете, можно использовать метод getcwd() из модуля os:
# ```python
# import os
# os.getcwd()
# ```

# %% [markdown]
# ---

# %%
a = '1'
b = '2'
c = '3's = a + ‘[‘ + b + ‘:’ + c + ‘]’
print(s)
# Out:
#   Cell In[4], line 3
#     c = '3's = a + ‘[‘ + b + ‘:’ + c + ‘]’
#                    ^
# SyntaxError: invalid character '‘' (U+2018)

# %% [markdown]
# ---

# %% [markdown]
# Как бы вы произвели рандомизацию содержимого списка на месте?
# Мы можем воспользоваться функцией shuffle() из модуля random:
# ```python
# from random import shuffle
# list_example = [1,2,3,4,5,6,7,8]
# shuffle(list_example)
# ```
# ---

# %% [markdown]
# Как получить текущую версию Python?
# Мы можем узнать текущую версию Python с помощью sys.version:
# ```python
# import sys
# sys.version
# ```
# ---

# %% [markdown]
# Что за функции help() и dir() в Python?
# Функция help() отображает строку документации и справку для своего аргумента.
# ```python
# import numpy
# help(numpy.array)
# ```
# Функция dir() отображает все элементы объекта (любого вида).
# ```python
# import numpy
# dir(numpy.array)
# ```
# ---

# %% [markdown]
# Что означает одинарное и двойное подчеркивание перед именем объекта?
# Одиночное подчеркивание — имена в классе с подчеркиванием перед ними просто указывают другим программистам, что атрибут или метод предназначен для закрытого использования, однако с самим именем ничего особенного не делается.
#
# Двойное подчеркивание (искажение имени) — любой идентификатор вида __spam (не менее двух ведущих подчеркиваний, не более одного завершающего) заменяется на _имякласса__spam, где имя класса — это текущее спрятанное имя с подчеркиванием перед ним. Это искажение выполняется без учета синтаксической позиции идентификатора, поэтому его можно использовать для определения экземпляра закрытого класса и его переменных, методов, а также глобальных и других переменных, хранящихся в экземплярах, частных для этого класса в экземплярах других.

# %% [markdown]
# ---

# %%
#Напишите программу на Python, чтобы создать треугольник из звезд
def star_triangle(r):
   for x in range(r):
      print(' '*(r-x-1)+'*'*(2*x+1))

star_triangle(7)
# Out:
#       *
#      ***
#     *****
#    *******
#   *********
#  ***********
# *************

# %%
#Напишите программу на Python, чтобы проверить, является ли последовательность, которую вы вводите, палиндромом
a=input("enter the sequence: ")
b=a[::-1]

if a==b:
   print("palindrome")
else:
   print("Not a Palindrome")
# Out:
# palindrome

# %% [markdown]
# Что такое генератор?
# Генератор Python создает последовательность значений для итерации, часто с помощью функции. Мы определяем функцию с помощью yield , которая используется для получения значения по одному, а затем используем цикл for для итерации.

# %%
def squares(n):
    i=1
    while(i<=n):
        yield i**2
        i+=1
for i in squares(7):
    print(i)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49

# %% [markdown]
# Напишите программу на Python для проверки, является ли число простым

# %%
a=int(input("enter a number"))     
if a>1:
    for x in range(2,a):
        if(a%x)==0:
            print("not prime")
            break
    else:
        print("Prime")
else:
    print("not prime")
# Out:
# Prime

# %% [markdown]
# Какова цель одинарной переменной подчеркивания ( ‘ _ ’ ) в Python?
#
# Она предназначена для хранения результата последнего выполненного выражения (/statement) в сеансе интерактивного интерпретатора. Этот прецедент был установлен стандартным интерпретатором CPython, а другие последовали этому примеру.

# %% [markdown]
# ---

# %% [markdown]
# Каковы типы наследования в Python?
# Python поддерживает различные типы наследования. Ими являются:
#
# единичное наследование;
# многоуровневое наследование;
# иерархическое наследование;
# множественное наследование.

# %% [markdown]
# ---

# %% [markdown]
# Освобождается ли вся память при выходе из Python?
# Выход из Python освобождает все, кроме:
#
# 1. модулей с циклическими ссылками;
#
# 2. объектов, на которые ссылаются глобальные пространства имен;
#
# 3. части памяти, зарезервированной библиотекой C.

# %% [markdown]
# ---

# %% [markdown]
# Является ли функция допустимой, если она не имеет оператора return?
# Функция, которая ничего не возвращает, возвращает объект None. Ключевое слово return необязательно обозначает конец функции, оно просто завершает ее, если присутствует. Обычно блок кода помечает функцию, и там, где заканчивается блок, заканчивается и тело функции.

# %%
config = {
    "server": {
        "host": "127.0.0.1",
        "port": "22"
    },
    "configuration": {
        "ssh": {
            "access": True,
            "login": "some",
            "password": "some"
        },
        "name": "2491Oaaf1414"
    }
}
config['configuration']['ssh']['login']
# Out:
# 'some'

# %%
def apply_discounts(products, stocks):
    result = {} 
    for name, price in products.items():
        if name in stocks:
            discount_percent = int((stocks[name])[0:2])
            print(discount_percent)
 # Вычисляем новую цену с учётом скидки
            new_price = price * (1 - discount_percent/100)
 # Округляем до 2 знаков после запятой
            result[name] = round(new_price, 2)
        else:
 # Если товара нет в stocks, оставляем исходную цену
            result[name] = price
 
    return result

# %%
products = {'Oranges (packaged)': 114.99, 'Candy (Rotfront)': 280.0, 'Boiled sausage': 199.99, 'Juice J7 (orange)': 119.99, 'Trout (Seven Seas)': 399.99}
stocks = {'Boiled sausage': '33%', 'Juice J7 (orange)': '12%', 'Trout (Seven Seas)': '18%'}

print(apply_discounts(products, stocks))

## {'Oranges (packaged)': 114.99, 'Candy (Rotfront)': 280.0, 'Boiled sausage': 133.99, 'Juice J7 (orange)': 105.59, 'Trout (Seven Seas)': 327.99}
# Out:
# 33
# 12
# 18
# {'Oranges (packaged)': 114.99, 'Candy (Rotfront)': 280.0, 'Boiled sausage': 133.99, 'Juice J7 (orange)': 105.59, 'Trout (Seven Seas)': 327.99}

# %%
print(apply_discounts(products = {'Oranges (packaged)': 114.99, 'Candy (Rotfront)': 280.0, 'Boiled sausage': 199.99, 'Juice J7 (orange)': 119.99, 'Trout (Seven Seas)': 399.99}, stocks = {'Oranges (packaged)': '15%', 'Boiled sausage': '10%', 'Candy (Rotfront)': '50%', 'Diapers': '10%'}))
# Out:
# {'Oranges (packaged)': 113.84, 'Candy (Rotfront)': 266.0, 'Boiled sausage': 197.99, 'Juice J7 (orange)': 119.99, 'Trout (Seven Seas)': 399.99}

# %%
import pandas as pd
bronze_top = pd.read_csv('bronze_top.csv')
silver_top = pd.read_csv('silver_top.csv')

# %%
import pandas as pd

# %%
bronze_top = pd.DataFrame({
    'Country': ['Russia', 'USA', 'GB', 'China', 'France'],
    'Total': [10, 5, 6, 7, 9],
})
silver_top = pd.DataFrame({
    'Country': ['Russia', 'USA', 'Germany', 'China', 'India'],
    'Total': [7, 5, 6, 5, 1],
})

# %%
display(bronze_top)
display(silver_top)
# Out:
#   Country  Total
# 0  Russia     10
# 1     USA      5
# 2      GB      6
# 3   China      7
# 4  France      9
#    Country  Total
# 0   Russia      7
# 1      USA      5
# 2  Germany      6
# 3    China      5
# 4    India      1

# %%
merged = bronze_top.merge(
    silver_top,
    on='Country',
    how='inner',
    suffixes=('_bronze', '_silver')
)
display(merged)
# Out:
#   Country  Total_bronze  Total_silver
# 0  Russia            10             7
# 1     USA             5             5
# 2   China             7             5

# %%
solar_data = pd.read_csv('..\solarpower.csv', sep = ',')
solar_data.head()
# Out:
#          date  cum_power
# 0  2017-01-01    20111.0
# 1  2017-01-02    20112.0
# 2  2017-01-03    20115.0
# 3  2017-01-04    20117.0
# 4  2017-01-05    20119.0

# %%
# Функция для замены  
def replace_ones_with_average(series):  
    for i in range(1, len(series)-1):  
        if series[i] == -1:  
            # Вычисляем среднее соседних значений  
            average = (series[i-1] + series[i+1]) / 2  
            series[i] = average  
    return series

# %%
new_cum_power = replace_ones_with_average(row)
print(round(new_cum_power.mean()))
# Out:
# 23848

# %%
solar_data['cum_power'] = new_cum_power
solar_data['date'] = pd.to_datetime(solar_data['date'], dayfirst=False)

# %%
display(solar_data)
# Out:
#           date  cum_power
# 0   2017-01-01    20111.0
# 1   2017-01-02    20112.0
# 2   2017-01-03    20115.0
# 3   2017-01-04    20117.0
# 4   2017-01-05    20119.0
# ..         ...        ...
# 659 2018-10-22    28101.0
# 660 2018-10-23    28109.0
# 661 2018-10-24    28115.0
# 662 2018-10-25    28117.0
# 663 2018-10-26    28120.0
#
# [664 rows x 2 columns]

# %%
months = solar_data['date'].dt.to_period('M')
solar_data['months'] = months

# %%
years = solar_data['date'].dt.to_period('Y')
solar_data['years'] = years

# %%
solar_data['day_power'] = solar_data['cum_power'].diff()
display(solar_data)
# Out:
#           date  cum_power   months years  day_power
# 0   2017-01-01    20111.0  2017-01  2017        NaN
# 1   2017-01-02    20112.0  2017-01  2017        1.0
# 2   2017-01-03    20115.0  2017-01  2017        3.0
# 3   2017-01-04    20117.0  2017-01  2017        2.0
# 4   2017-01-05    20119.0  2017-01  2017        2.0
# ..         ...        ...      ...   ...        ...
# 659 2018-10-22    28101.0  2018-10  2018        6.0
# 660 2018-10-23    28109.0  2018-10  2018        8.0
# 661 2018-10-24    28115.0  2018-10  2018        6.0
# 662 2018-10-25    28117.0  2018-10  2018        2.0
# 663 2018-10-26    28120.0  2018-10  2018        3.0
#
# [664 rows x 5 columns]

# %%
mask = solar_data['months'] == 2017-03
res = solar_data

# %%
res = round(solar_data.groupby(by='months').mean(numeric_only=True))
display(res)
# Out:
#          cum_power  day_power
# months
# 2017-01    20153.0        3.0
# 2017-02    20257.0        4.0
# 2017-03    20445.0       11.0
# 2017-04    20885.0       16.0
# 2017-05    21408.0       19.0
# 2017-06    22068.0       22.0
# 2017-07    22667.0       18.0
# 2017-08    23179.0       15.0
# 2017-09    23573.0       12.0
# 2017-10    23858.0        6.0
# 2017-11    23999.0        3.0
# 2017-12    24059.0        1.0
# 2018-01    24104.0        2.0
# 2018-02    24225.0        7.0
# 2018-03    24461.0        9.0
# 2018-04    24815.0       15.0
# 2018-05    25387.0       21.0
# 2018-06    25959.0       19.0
# 2018-07    26625.0       22.0
# 2018-08    27245.0       17.0
# 2018-09    27692.0       14.0
# 2018-10    28024.0        9.0

# %%
grouped_cases = solar_data.groupby('months')['cum_power'].mean()
grouped_cases.plot(
    kind='line',
    figsize=(12, 4),
    title='Ежемесячная выработка электроэнергии',
    grid = True,
    lw=1
);

# %%
grouped_cases = solar_data.groupby('months')['cum_power'].mean()
grouped_cases.plot(
    kind='bar',
    grid=True,
    figsize=(12, 4),
    colormap='plasma'
);
