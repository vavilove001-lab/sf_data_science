# %% [markdown]
# На языке Python условный оператор записывается следующим образом:

# %%
if Условие:
    Блок инструкций 1
else:
    Блок инструкций 2

# %%
is_rainy = True  # дождь будет
 
# Реализуем условный оператор
# В блок if помещаем условие 
if is_rainy:
    # брать зонт
    print("Take an umbrella") 
else:
    # не брать зонт
    print("Don't take an umbrella")
# Out:
# Take an umbrella

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ВЛОЖЕННЫЕ УСЛОВНЫЕ ОПЕРАТОРЫ

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
is_rainy = True  # дождь будет
heavy_rain = False  # не сильный дождь

if is_rainy:
    # в данный блок дописали ещё один условный оператор
    if heavy_rain:
        #брать зонт
        print("Take an umbrella")  
    else:
        #надеть дождевик
        print("Put on a raincoat") 
else:
    #не брать зонт
    print("Don't take an umbrella")
# Out:
# Put on a raincoat

# %% [markdown]
# НЕЯВНОЕ ПРИВЕДЕНИЕ К БУЛЕВУ ТИПУ

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# *ТЕРНАРНЫЙ УСЛОВНЫЙ ОПЕРАТОР

# %%
a = 42
b = 41

if a > b:
    result = a
else:
    result = b

print(result)
# Out:
# 42

# %% [markdown]
# В зависимости от значения переменных a и b этот код присваивает переменной result значение большей из них.
#
# Код сравнения занимает аж четыре строки, а выполняет элементарное действие. Такое многословие не в стиле Python — нужно исправлять данную ситуацию!
#
# И здесь придёт на помощь так называемый тернарный условный оператор — оператор, который записывается в одну строку.

# %% [markdown]
# Шаблон синтаксиса тернарного оператора:

# %%
variable = <значение при выполнении условия> if <условие> else <значение при невыполнении условия>

# %% [markdown]
# Тогда с его помощью можно переписать код следующим образом:

# %%
result = a if a > b else b

print(result)
# Out:
# 42

# %% [markdown]
# Мы реализуем систему скидок по возрасту в приложении для бронирования мероприятий. Клиент может рассчитывать на скидку, если его возраст выше 60 лет.
#
# В переменной cust_age содержится значение возраста клиента. Программа должна выводить на экран фразу "Eligible for discount", если у клиента есть право на скидку и "Not eligible for discount", если такого права нет.
#
# Без использования тернарного оператора наша программа выглядела бы следующим образом:

# %%
cust_age = 40
# Проверяем условие: возраст больше 60 
if cust_age >= 60:
    # условие выполняется
    print("Eligible for discount")
else:
    # условие не выполняется
    print("Not eligible for discount")
# Out:
# Not eligible for discount

# %% [markdown]
# Создадим переменную cust_discount, в которую запишем результат работы тернарного условного оператора, а затем просто выведем этот результат на экран. Тогда наш код сократится до двух строчек кода:

# %%
cust_age = 40
# Реализуем тот же код через тернарный оператор
cust_discount = "Eligible for discount" if cust_age >= 60 else "Not eligible for discount"
print(cust_discount)
# Out:
# Not eligible for discount

# %% [markdown]
# Тернарный условный оператор применяется только в том случае, если внутри условного оператора присваивается значение переменной. Если действий внутри блоков больше, использовать тернарный оператор невозможно.

# %% [markdown]
# Условия, которые никогда не могут быть выполнены одновременно, называются взаимоисключающими. И для обработки таких условий лучше всего подойдёт не множественный if, а конструкция if-elif-else.

# %% [markdown]
# Вы работаете в агентстве знакомств. К вам обратилась некая Алла, которая ищет мужчину ростом строго выше 180 см, весом строго менее 80 кг. Также Алла верит в гороскопы и согласно гороскопу ей подходят только весы, дева, овен и козерог.
#
# Напишите условие, которое позволит определить, подходит ли Алле тот или иной кандидат. В результате работы программы на экран должно быть введено:
#
# «Ваша половинка нашлась!» — если кандидат подходит Алле по параметрам.
#
# «Попробуем поискать еще!» — если кандидат не подходит Алле по параметрам.

# %%
height = 165
weight = 78
zodiac_sign = 'овен'
zodiac_list = ['весы', 'дева', 'овен', 'козерог']
if (height > 180) and (weight < 80) and (zodiac_sign in zodiac_list):
    print('Ваша половинка нашлась!')
else:
    print('Попробуем поискать еще!')
# Out:
# Попробуем поискать еще!

# %% [markdown]
# ## КОНСТРУКЦИЯ IF-ELIF-ELSE

# %% [markdown]
# if Условие 1:
#
#     Блок инструкций 1
#
# elif Условие 2:
#
#     Блок инструкций 2
#
# ...
# elif Условие n:
#
#     Блок инструкций n
#
# else:
#
#     Блок инструкций n+1

# %% [markdown]
# То есть к условному оператору if-else добавляется условие elif, которое можно интерпретировать как «а если…». Оператор elif, так как же как и оператор if, должен содержать условие — выражение, результатом которого является True или False. Блоков elif может быть сколько угодно много, блок else может быть только один, но также является необязательным.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Конструкция if-elif-else — это единое целое, один условный оператор. То есть если условие if или какого-либо elif по порядку выполняется, то программа сразу переходит в основную ветку программы (нижний голубой прямоугольник), а все нижестоящие elif пропускаются.
#
# Если же ни одно из условий, заявленных в if и elif, не выполняется, выполняется код, записанный в блоке else.

# %% [markdown]
# ** Необходимо реализовать условный оператор, который печатает на экран характеристику ветра и его класс (от 1 до 4) в зависимости от его характера:
#
# "weak [1]" — от 1 до 4 м/с
#
# "moderate [2]" — от 5 до 10 м/c
#
# "strong [3]" — от 11 до 18 м/c
#
# "hurricane [4]" — от 19 м/c
#
# Скорость ветра хранится в переменной speed.

# %%
speed = 0
if 1 <= speed <= 4:  
    print("weak [1]")  
elif 5 <= speed <= 10:  
    print("moderate [2]")  
elif 11 <= speed <= 18:  
    print("strong [3]")  
elif speed >= 19:  
    print("hurricane [4]")  
else:  
    print("Invalid speed value")
# Out:
# Invalid speed value

# %% [markdown]
# Друг, зная, что вы отличный программист, попросил вас запрограммировать игру «Камень, ножницы, бумага» для своего младшего брата. Правила игры всем известны: камень побеждает ножницы; ножницы — бумагу; бумага — камень.
#
# Жесты, выполняемые первым и вторым игроками находятся в переменных player_1 и player_2 соответственно. Обратите внимание, что названия жестов должны быть написаны строчными буквами.
#
# Напишите программу, которая определяет победителя. Если побеждает первый игрок, то выводится сообщение «Первый игрок — победитель!». Если второй — «Второй игрок — победитель!». Если ничья — выводится «Ничья!».

# %%
player_1 = 'ножницы'
player_2 = 'камень'

if player_1 == 'камень':
    if player_2 == 'ножницы':
        print('Первый игрок — победитель!')
    elif player_2 =='камень':
        print('Ничья!')
    elif player_2 == 'бумага':
        print('Второй игрок — победитель!')
elif player_1 == 'ножницы':
    if player_2 == 'бумага':
        print('Первый игрок — победитель!')
    elif player_2 =='ножницы':
        print('Ничья!') 
    elif player_2 == 'камень':
        print('Второй игрок — победитель!')
elif player_1 =='бумага':
    if player_2 =='камень':
        print('Первый игрок — победитель!')
    elif player_2 =='бумага':
        print('Ничья!') 
    elif player_2 == 'ножницы':
        print('Второй игрок — победитель!')
# Out:
# Второй игрок — победитель!

# %% [markdown]
# ** Задача №4
#
# Условие задачи:
#
# Мы занимаемся разработкой сервиса доставки еды из нашего ресторана. В словаре dish_time_dict представлены блюда, которые в данный момент ресторан может приготовить и среднее время их приготовления (в минутах).

# %%
dish_time_dict = {
    'Рамен с говядиной': 15,
    'Суши': 18,
    'Лагман с курицей': 20,
    'Лагман с говядиной': 24,
    'Плов с курицей': 28
}

# %%
street_time_dict  = {
    'Дзержинский': 39,
    'Солнечный': 40,
    'Заводской': 27,
    'Гагаринский': 43,
    'Кировский': 37,
    'Октябрьский': 34
}

# %%
if street not in street_time_dict: 
    # неизвестный район
    print("Доставка в ваш район недоступна")
elif dish not in dish_time_dict:
    # неизвестное блюдо
    print("Блюдо недоступно, закажите что-то другое") 
else: 
    # район доступен для доставки и блюдо известно
    dish_time = dish_time_dict[dish] # время приготовления блюда
    street_time = street_time_dict[street] # время доставки
    full_time = dish_time + street_time  # общее время доставки
    delay = full_time - 60  # задержка
    if delay <= 0: 
        # задержка не положительна
        print("Заказ будет доставлен вовремя")
    else:  
        # задержка положительная
        print("Курьер задержится на {} минут".format(delay))
        
        
dish, street = 'Рамен с говядиной', 'Заводской'
## Заказ будет доставлен вовремя

dish, street = 'Плов с курицей', 'Солнечный'
## "Курьер задержится на 8 минут" 

dish, street = 'Бургер с говядиной', 'Солнечный'
## "Блюдо недоступно, закажите что-то другое"
# Out:
# Блюдо недоступно, закажите что-то другое

# %% [markdown]
# Задача №6
#
# Условие задачи:
#
# Представим ситуацию. В последний месяц удача перестала вам улыбаться. У вас 3 раза взломали пароль от вашего профиля в соцсетях. Вы задумались над тем, что неправильно подходите к вопросу безопасности. И решаете написать программу на Python, которая будет проверять ваш пароль на надёжность. Немного погуглив, вы смогли составить список рекомендаций к паролю:
#
# Длина – 8 символов (если меньше – то проще взломать, а если длиннее – то сложно запомнить).
# Пароль не должен состоять только из цифр.
# Пароль не должен состоять только из букв.
# В пароле должны быть заглавные буквы.
# В пароле должны быть строчные символы.
# В пароле должен быть хотя бы один из специальных символов ('*', '-', '#'), но каждый из символов должен входить в пароль не более 1 раза.
# Другие спецсимволы недопустимы, так как вы их не можете запомнить. Вот список «плохих» символов: '!', '@', '$', '%', '^', '`', '&', '(', ')', '+', '=', '_', '~'.
# В случае надёжного пароля программа должна выводить фразу «Пароль идеален!», а в остальных случаях будут перечислены все ошибки, которые вы допустили.

# %%
errors_dict = {
    'length': 'Длина пароля не равна 8 символам',
    'digits': 'Пароль состоит только из цифр',
    'letters': 'Пароль состоит только из букв',
    'upper': 'Отсутствуют заглавные буквы',
    'lower': 'Отсутствуют строчные буквы',
    'spec': 'Отсутствуют спецсимволы в пароле',
    'bad_symbols': 'В пароле использованы непредусмотренные символы'
}
bad_symbols = ['!', '@', '$', '%', '^', '`', '&', '(', ')', '+', '=', '_', '~']
password = 'Aafaf*al'
# Проверяем длину пароля
if len(password) == 8:
    errors_dict.pop('length')

# Проверяем, что пароль НЕ состоит только из цифр
if not password.isdigit():
    errors_dict.pop('digits')

# Проверяем, что пароль НЕ состоит только из букв
if not password.isalpha():
    errors_dict.pop('letters')

# Проверяем, есть ли в пароле заглавные буквы
if password.lower() != password:
    errors_dict.pop('upper')

# Проверяем, есть ли в пароле строчные буквы
if password.upper() != password:
    errors_dict.pop('lower')

# Проверяем, есть ли в пароле специальные символы
if '*' in password or '-' in password or '#' in password:
    errors_dict.pop('spec')
    # Проверяем, встречаются ли спец символы в пароле несколько раз
    if password.count('*') > 1 or password.count('-') > 1 or password.count('#') > 1:
        errors_dict['spec_count'] = 'Какой-то из спецсимволов в пароле использован более одного раза'

# Проверяем, есть ли в пароле запрещенные символы
if len(set(password).intersection(set(bad_symbols))) == 0:
    errors_dict.pop('bad_symbols')

# Проверяем результирующую длину чек-листа
if len(errors_dict) > 0:
    print(list(errors_dict.values()))
else:
    print('Пароль идеален!')
# Out:
# Пароль идеален!

# %% [markdown]
# Обдумывая акцию для распродажи, владелец компании пришёл к выводу, что продавать все кроссовки по акции на сайте компании невыгодно. Поэтому была придумана новая схема: если клиент покупает одновременно кроссовки двух разных брендов, то его общая скидка составит 5 %, если две пары от одного бренда — то 10 %.
#
# Для упрощения задачи будем считать, что покупатель в любом случае купит не более двух пар кроссовок. Список товаров в корзине хранится в переменной purchases и может быть пустым.
#
# Также будем считать, что для всех товаров бренда действует одна и та же цена. Расценки товаров хранятся в словаре prices:
#
#
# prices = {'Adidas': 4298, 'Nike': 6550, 'Puma': 4490, 'Asics': 3879}
# Напишите программу, которая:
#
# Выводит на экран информацию об ошибке, если список покупок пуст в виде строки: Ваша корзина пуста
#
# Выводит на экран информацию об общей стоимости товара, если куплен только один товар Стоимость заказа составила: <стоимость заказа>
#
# Выводит на экран информацию о полученной скидке, сумме оплаты без скидки и сумму со скидкой в следующем формате:

# %%
prices = {'Adidas': 4298, 'Nike': 6550, 'Puma': 4490, 'Asics': 3879}
# корзина клиента
purchases = []

# проверка на пустую корзину
if len(purchases) == 0:
    print('Ваша корзина пуста')
# проверка на 1 товар в корзине
elif len(purchases) == 1:
    key1 = purchases[0]
    money = prices.get(key1)
    print('Стоимость заказа составила:', money)
# проверка на 2 товара в корзине
elif len(purchases) == 2:
    key1 = purchases[0]
    key2 = purchases[1]
    money1 = prices.get(key1)
    
    # если бренды одинаковые, то считаем общую стоимость и скидку
    if key1 == key2:
        money2 = money1 * 2
        discount = 0.9 * money2
        print(f'Стоимость заказа составила: {money2}. С учетом скидки в 10% — {discount}')
    # если бренды разные
    else:
        money3 = prices.get(key2)
        total = money1 + money3
        total_discount = 0.95 * total
        print(f'Стоимость заказа составила: {total}. С учетом скидки в 5% — {total_discount}')
# Out:
# Ваша корзина пуста
